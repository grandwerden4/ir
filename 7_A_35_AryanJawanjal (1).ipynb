# %% [markdown]
# ## Name : Aryan Jawanjal
# ## Branch : CSE
# ## Roll no.: A2-35
# ## IR Practical 1

# %% [markdown]
# ## Practical No. 1 :
# ## Implement text preprocessing techniques: Tokenization, Stop-word Removal, Stemming and Lemmatization.

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

nltk.download('punkt_tab')
text="Hello, I am student of rcoem doing my btech in computer science and engineering"
sentences = sent_tokenize(text)
words = word_tokenize(text)

print("Sentences:", sentences)
print("Words:", words)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Sentences: ['Hello, I am student of rcoem doing my btech in computer science and engineering']
# Words: ['Hello', ',', 'I', 'am', 'student', 'of', 'rcoem', 'doing', 'my', 'btech', 'in', 'computer', 'science', 'and', 'engineering']

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.lower() not in stop_words]
print("Filtered Words:", filtered_words)
# Out:
# Filtered Words: ['Hello', ',', 'student', 'rcoem', 'btech', 'computer', 'science', 'engineering']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_words]
print("Stemmed Words:", stemmed_words)
# Out:
# Stemmed Words: ['hello', ',', 'student', 'rcoem', 'btech', 'comput', 'scienc', 'engin']

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]
print("Lemmatized Words:", lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Lemmatized Words: ['Hello', ',', 'student', 'rcoem', 'btech', 'computer', 'science', 'engineering']

# %%
def preprocess(text):
  tokens = word_tokenize(text)
  stop_words = set(stopwords.words('english'))
  filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
  stemmer = PorterStemmer()
  stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]
  lemmatizer = WordNetLemmatizer()
  lemmatized = [lemmatizer.lemmatize(word) for word in stemmed_tokens]
  return tokens, filtered_tokens, stemmed_tokens, lemmatized

text = "The children were playing happily in the park"
tokens, fildered, stemmed, lemmatized_words = preprocess(text)
print("Tokens:", tokens)
print("Filtered Words:", fildered)
print("Stemmed Words:", stemmed)
print("Lemmatized Words:", lemmatized_words)
# Out:
# Tokens: ['The', 'children', 'were', 'playing', 'happily', 'in', 'the', 'park']
# Filtered Words: ['children', 'playing', 'happily', 'park']
# Stemmed Words: ['children', 'play', 'happili', 'park']
# Lemmatized Words: ['child', 'play', 'happili', 'park']
